# %% [markdown]
# <a href="https://colab.research.google.com/github/Kevinx45/gMicroMC/blob/master/Copy_of_gMicroMC_sample.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! nvidia-smi
# Out:
# Wed Jun 28 18:07:10 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8    12W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !pip install git+https://github.com/andreinechaev/nvcc4jupyter.git
# Out:
# ...
#   Cloning https://github.com/andreinechaev/nvcc4jupyter.git to /tmp/pip-req-build-3r9hfrua
#   Running command git clone --filter=blob:none --quiet https://github.com/andreinechaev/nvcc4jupyter.git /tmp/pip-req-build-3r9hfrua
#   Resolved https://github.com/andreinechaev/nvcc4jupyter.git to commit aac710a35f52bb78ab34d2e52517237941399eff
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for NVCCPlugin: filename=NVCCPlugin-0.0.2-py3-none-any.whl size=4287 sha256=130152132bc69a2b8b58021adffe7abc3e20bdcffba05a324609712f75dce138
#   Stored in directory: /tmp/pip-ephem-wheel-cache-bc1g_xwv/wheels/a8/b9/18/23f8ef71ceb0f63297dd1903aedd067e6243a68ea756d6feea
# Successfully built NVCCPlugin
# ...

# %%
# %load_ext nvcc_plugin
# Out:
# created output directory at /content/src
# Out bin /content/result.out

# %%
# !git clone https://github.com/Kevinx45/gMicroMC
# Out:
# Cloning into 'gMicroMC'...
# remote: Enumerating objects: 111, done.
# remote: Counting objects: 100% (111/111), done.
# remote: Compressing objects: 100% (101/101), done.
# remote: Total 111 (delta 11), reused 107 (delta 10), pack-reused 0
# Receiving objects: 100% (111/111), 37.70 MiB | 24.14 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
# %cd gMicroMC
# !nvcc main.cpp ./src/* -o gMicroMC -I ./inc -rdc=true
# !./gMicroMC
# Out:
# [Errno 20] Not a directory: 'gMicroMC'
# /content/gMicroMC
# ./src/chemicalKernel.cu(97): warning #177-D: variable "tid" was declared but never referenced
#
# ./src/chemicalKernel.cu(224): warning #1215-D: function "tex1Dfetch(texture<T, 1, cudaReadModeElementType>, int) [with T=float]"
# /usr/local/cuda/bin/../targets/x86_64-linux/include/texture_fetch_functions.h(132): here was declared deprecated
#
# ./src/chemicalKernel.cu(225): warning #1215-D: function "tex1Dfetch(texture<T, 1, cudaReadModeElementType>, int) [with T=float]"
# /usr/local/cuda/bin/../targets/x86_64-linux/include/texture_fetch_functions.h(132): here was declared deprecated
#
# ./src/chemicalKernel.cu(226): warning #1215-D: function "tex1Dfetch(texture<T, 1, cudaReadModeElementType>, int) [with T=float]"
# /usr/local/cuda/bin/../targets/x86_64-linux/include/texture_fetch_functions.h(132): here was declared deprecated
#
# ...

# %%
# !make
# Out:
# nvcc main.cpp src/globalKernel.cu src/prechemical.cpp src/initialize.cpp src/physicsList.cpp src/DNAList.cpp src/chemical.cpp src/prechemicalKernel.cu src/physicsKernel.cu src/DNAKernel.cu src/chemicalKernel.cu -dc -I ./inc -std=c++14 -dlto -w
# mv *.o obj
# nvcc obj/chemical.o obj/prechemicalKernel.o obj/physicsKernel.o obj/main.o obj/DNAKernel.o obj/chemicalKernel.o obj/prechemical.o obj/globalKernel.o obj/initialize.o obj/physicsList.o obj/DNAList.o -o gMicroMC
